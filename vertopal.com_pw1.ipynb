# %% [markdown]
# Untitled1
#
# April 18, 2023
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>[ ]: 1.</p>
# <blockquote>
# <p>In object-oriented programming (OOP), a <strong>class is</strong> a
# blueprint <strong>or</strong> template that␣</p>
# <p>of a type of object. An object, on the other hand,
# <strong>is</strong> an instance of a <strong>class</strong>␣↪defines the
# properties <strong>and</strong> behaviors (methods)<br />
# ↪<strong>that</strong> represents a specific entity
# <strong>with</strong> its own</p>
# <p>let's consider the example of a "Car" class. The "Car" class might
# have␣</p>
# <p>"mileage", etc. It might also have methods such <strong>as</strong>
# "start_engine",␣↪properties such as "make", "model", "year",
# "color",<br />
# ↪"accelerate", "brake", <strong>and</strong> "turn_off_engine".</p>
# <p>Once we have defined the "Car" class, we can create multiple
# instances of this␣</p>
# <p>For example, we might create an object of the "Car" <strong>class
# to</strong> represent a 2019␣↪class, each representing a specific
# car.</p>
# <p>another object to represent a 2021 Honda Civic <strong>with</strong>
# 10,000 miles on it.↪Toyota Corolla <strong>with</strong> 25,000 miles on
# it, <strong>and</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Here <strong>is</strong> an example:<br />
# <strong>class Car</strong>:<br />
# <strong>def</strong> _init_(self, make, model, year, color, mileage):
# self.make = make<br />
# self.model = model<br />
# self.year = year<br />
# self.color = color<br />
# self.mileage = mileage</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > **def** start_engine(self):
# > **def** accelerate(self):
# > **def** brake(self):
# > **def** turn_off_engine(self):
# > To create an instance of the "Car" class, we would call its
# > constructor **and**␣ ↪provide the necessary parameters:
# > 1
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>my_car = Car("Toyota", "Corolla", 2019, "red", 25000)<br />
# Now we have an object named "my_car" that represents a specific car
# <strong>with</strong> a make␣</p>
# <p>a year of 2019, a color of "red", <strong>and</strong> a mileage of
# 25,000. We can access its␣↪of "Toyota", a model of "Corolla",<br />
# ↪properties <strong>and</strong> methods using dot notation:<br />
# print(my_car.make)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>output: "Toyota"</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>my_car.start_engine()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>runs the code to start the car's engine</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>The four pillars of Object-Oriented Programming (OOP) are:</p>
# </blockquote>
# <p>1.Encapsulation: Encapsulation <strong>is</strong> the process of
# bundling data <strong>and</strong> methods that␣</p>
# <blockquote>
# <p>object. The purpose of encapsulation <strong>is</strong> to restrict
# access to the data <strong>from</strong>␣↪act on that data within a
# single unit <strong>or</strong></p>
# <p>methods to interact <strong>with</strong> it. This helps to prevent
# accidental modification of␣↪<strong>outside</strong> the object
# <strong>and</strong> only allow the object's</p>
# <p>↪the data <strong>and</strong> ensures that the object remains
# <strong>in</strong></p>
# <p>2.Abstraction: Abstraction <strong>is</strong> the process of hiding
# the implementation details␣</p>
# </blockquote>
# <p>features that are relevant to the user. Abstraction allows the user
# to focus on␣↪of an object <strong>and</strong> only exposing the
# essential</p>
# <blockquote>
# <p>it. This helps to simplify the code <strong>and</strong> makes it
# easier to understand <strong>and</strong>␣↪what the object does rather
# than how it does</p>
# <p>↪maintain.</p>
# </blockquote>
# <p>3.Inheritance: Inheritance <strong>is</strong> the process of
# creating new classes <strong>from existing</strong>␣</p>
# <blockquote>
# <p>behaviors. Inheritance allows <strong>for</strong> code reusability
# <strong>and</strong> the creation of a␣↪classes by inheriting their
# properties <strong>and</strong></p>
# <p>the characteristics of its parent <strong>class and</strong> can also
# add its own unique␣↪hierarchical <strong>class structure</strong>. A
# derived <strong>class inherits</strong></p>
# <p>↪characteristics.</p>
# <p>4.Polymorphism: Polymorphism <strong>is</strong> the ability of
# objects of different classes to␣</p>
# <p>common interface <strong>or</strong> parent class. Polymorphism
# allows <strong>for</strong> flexibility <strong>in</strong> the␣↪be used
# interchangeably, <strong>as</strong> long <strong>as</strong> they have
# a</p>
# </blockquote>
# <p>It enables objects to take on different forms <strong>or</strong>
# behaviors based on the context␣↪design of classes <strong>and</strong>
# promotes code reuse.</p>
# <blockquote>
# <p>↪<strong>in</strong> which they are used.</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[ \]: 2.
#
# 2
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Overall, the four pillars of OOP provide a framework
# <strong>for</strong> organizing
# <strong>and</strong>␣maintainable.↪structuring code <strong>in</strong>
# a way that <strong>is</strong> both flexible <strong>and</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[ \]: 3.
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In Python, the _init_() function <strong>is</strong> used
# <strong>as</strong> a constructor method <strong>for</strong>␣<br />
# This function <strong>is</strong> called automatically when an object
# <strong>is</strong> created <strong>from a class</strong>␣↪initializing
# newly created objects of a class.</p>
# <p>↪<strong>and is</strong> used to initialize the object's
# attributes.</p>
# <p>The _init_() function <strong>is</strong> a special method
# <strong>in</strong> Python <strong>and is</strong> defined
# <strong>with</strong> two␣It takes the self parameter, which refers to
# the object being created, <strong>and</strong> any␣↪underscores on
# either side of the method name.</p>
# <p>↪additional parameters that are required to</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Here **is** an example to help illustrate the use of the \_init\_()
# > function:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Person</strong>:<br />
# <strong>def</strong> _init_(self, name, age):<br />
# self.name = name<br />
# self.age = age</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> introduce(self):<br />
# print(f"My name is <strong>{</strong>self.name<strong>}</strong> and I
# am <strong>{</strong>self.age<strong>}</strong> years old.")<br />
# person1 = Person("Kavya", 22)<br />
# person1.introduce()<br />
# output: "My name is Kavya and I am 22 years old."<br />
# In the example above, we defined a Person <strong>class with</strong> an
# _init_() function that␣We then used these parameters to initialize the
# name <strong>and</strong> age attributes of the␣↪takes two parameters:
# name <strong>and</strong> age.</p>
# <p>↪object being created.</p>
# <p>We also defined an introduce() method which prints out the name
# <strong>and</strong> age of the␣object named person1
# <strong>with</strong> the name "Kavya and age 22, and called
# the␣↪object. Finally, we created a new Person<br />
# ↪introduce() method on it.</p>
# </blockquote>
# <p>[ ]: 4.</p>
# <blockquote>
# <p>In Object-Oriented Programming (OOP), the self keyword
# <strong>is</strong> used to refer to the␣↪current object
# <strong>or</strong> instance of a class. It <strong>is</strong> a
# reference to the memory location where the object <strong>is</strong>
# stored <strong>and</strong> allows␣↪us to access <strong>and</strong>
# manipulate the object's</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 3
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th colspan="2"><blockquote>
# <p>attributes <strong>and</strong> methods.</p>
# <p>When we create an object of a <strong>class in</strong> Python, we
# are essentially creating a␣set of attributes <strong>and</strong>
# methods. These attributes <strong>and</strong> methods are specific
# to␣↪new instance of that <strong>class with</strong> its own<br />
# ↪that instance <strong>and</strong> can be accessed <strong>and</strong>
# modified</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>Here's an example to</td>
# <td><blockquote>
# <p>illustrate the use of the self keyword:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Person</strong>:<br />
# <strong>def</strong> _init_(self, name, age):<br />
# self.name = name<br />
# self.age = age</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > **def** introduce(self):
# > print(f"My name is **{**self.name**}** and I am **{**self.age**}**
# > years old.")
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>person1 = Person("Kavya", 22)<br />
# person1.introduce()<br />
# output: "My name is Kavya and I am 22 years old."</p>
# <p>In the example above, we defined a Person <strong>class with</strong>
# an _init_() function that␣</p>
# <p>We used the self keyword to create instance variables name
# <strong>and</strong> age that are␣↪takes two parameters: name
# <strong>and</strong> age.</p>
# <p>↪specific to the object being created.</p>
# <p>We then defined an introduce() method that uses the self keyword to
# access the␣ ↪name <strong>and</strong> age attributes of the object</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Finally, we created a new Person object named person1
# <strong>with</strong> the name "Kavya" <strong>and</strong>␣ ↪age 22,
# <strong>and</strong> called the introduce() method on</p>
# <p>In summary, the self keyword <strong>is</strong> used
# <strong>in</strong> OOP to refer to the current object
# <strong>or</strong>␣</p>
# <p><strong>and</strong> manipulate the object's attributes and methods,
# which are specific to that␣↪instance of a class. It allows us to
# access<br />
# ↪instance.</p>
# </blockquote>
# <p>[ ]: 5.</p></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Inheritance <strong>is</strong> one of the key concepts
# <strong>in</strong> Object-Oriented Programming (OOP)␣</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > ↪that allows a new **class to** be based on an
# > 4
# >
# > existing class, inheriting its attributes **and** methods. Inheritance
# > **is** used to␣
# >
# > more specific classes inheriting **from more** general classes.↪create
# > a hierarchy of related classes, **with**
# >
# > There are four types of inheritance **in** Python:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1.Single inheritance: A new <strong>class inherits</strong> the
# attributes <strong>and</strong> methods of a␣ ↪single existing class.
# This <strong>is</strong> the most common</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Animal</strong>:<br />
# <strong>def</strong> _init_(self, name):<br />
# self.name = name</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > **def** eat(self):
# > print(f"**{**self.name**}** is eating.")
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Dog</strong>(Animal):<br />
# <strong>def</strong> bark(self):<br />
# print("Woof!")</p>
# <p>dog1 = Dog("Buddy")<br />
# dog1.eat()<br />
# Output: "Buddy is eating."<br />
# dog1.bark()<br />
# Output: "Woof!"<br />
# In the example above, we defined a Animal <strong>class with</strong> an
# _init_() function that␣</p>
# <p>We then defined a Dog <strong>class that</strong> inherits
# <strong>from the</strong> Animal <strong>class using</strong> the␣↪takes
# a name parameter <strong>and</strong> an eat() method.</p>
# <p>↪syntax <strong>class Dog</strong>(Animal):.</p>
# <p>The Dog <strong>class inherits</strong> the name attribute
# <strong>and</strong> eat() method <strong>from the</strong> Animal␣</p>
# <p>We created a new Dog object named dog1 <strong>with</strong> the name
# "Buddy" <strong>and</strong> called the␣↪class, <strong>and</strong>
# also has its own bark() method.</p>
# <p>↪eat() <strong>and</strong> bark() methods on it.</p>
# <p>2.Multiple inheritance: A new <strong>class inherits</strong> the
# attributes <strong>and</strong> methods of␣</p>
# <p><strong>class A</strong>:↪multiple existing classes.<br />
# <strong>def</strong> foo(self):<br />
# print("A")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class B</strong>:<br />
# <strong>def</strong> foo(self):<br />
# print("B")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 5
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th colspan="2"><blockquote>
# <p><strong>class C</strong>(A, B):<br />
# <strong>pass</strong></p>
# <p>c1 = C()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>c1.foo()</td>
# <td><blockquote>
# <p><em># Output: "A"</em></p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td colspan="2"><blockquote>
# <p>In the example above, we defined two classes A <strong>and</strong> B
# <strong>with</strong> a foo() method that␣<strong>that</strong> inherits
# <strong>from both</strong> A <strong>and</strong> B using the syntax
# <strong>class C</strong>(A, B):.↪prints a string. We then defined a C
# <strong>class</strong></p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>The C <strong>class inherits</strong> the foo() method <strong>from
# both</strong> A <strong>and</strong> B, but since A <strong>is</strong>
# listed␣ ↪first <strong>in</strong> the inheritance list, its foo()</p>
# <p>3.Hierarchical inheritance: A new <strong>class inherits from
# a</strong> single existing class,␣</p>
# <p>class.↪<strong>and</strong> other classes inherit <strong>from
# the</strong> same existing</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Animal</strong>:<br />
# <strong>def</strong> _init_(self, name):<br />
# self.name = name</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > **def** eat(self):
# > print(f"**{**self.name**}** is eating.")
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Dog</strong>(Animal):<br />
# <strong>def</strong> bark(self):<br />
# print("Woof!")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Cat</strong>(Animal):<br />
# <strong>def</strong> meow(self):<br />
# print("Meow!")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>dog1 = Dog("Buddy")<br />
# dog1.eat()<br />
# Output: "Buddy is eating."<br />
# dog1.bark()<br />
# output: "Woof!"</p>
# <p>cat1 = Cat("Whiskers")<br />
# cat1.eat()<br />
# Output: "Whiskers is eating."<br />
# cat1.meow()<br />
# Output: "Meow!"<br />
# In the example above, we defined a Animal <strong>class with</strong> an
# _init_() function that␣</p>
# <p>We then defined two classes Dog <strong>and</strong> Cat that inherit
# <strong>from the</strong> Animal <strong>class</strong>␣↪takes a name
# parameter <strong>and</strong> an eat() method.<br />
# ↪<strong>using</strong> the syntax <strong>class Dog</strong>(Animal):
# <strong>and class</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 6
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>Cat</strong>(Animal):.</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>The Dog <strong>and</strong> Cat classes inherit the name attribute
# <strong>and</strong> eat() method <strong>from the</strong>␣</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > ↪Animal **class**
#
# 7
